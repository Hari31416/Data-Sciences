# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\harik\Downloads\Regarding going to campus next semester.csv\Regarding going to campus next semester.csv")

# %%
df[df['Do you want to go to campus the next semester ?'] == 'May go'].drop('Timestamp', axis=1)
# Out:
#    Please enter your name . Do you want to go to campus the next semester ?
# 0                    Shirsh                                          May go
# 2          Harsh Khandelwal                                          May go
# 4             Nishant Dabur                                          May go
# 5         Harikesh Kushwaha                                          May go
# 6       Shailja Kant Tiwari                                          May go
# 8       Rakesh Kumar Behera                                          May go
# 9               2021PHS7179                                          May go
# 11                  Prajwal                                          May go
# 12        Pawan kumar singh                                          May go
# 14              2021phs7226                                          May go
# 16             Astha Mittal                                          May go
# ...

# %%
df.to_csv(r"C:\Users\harik\Downloads\Regarding going to campus next semester.csv\Regarding going to campus next semester 2.csv", index=False)
