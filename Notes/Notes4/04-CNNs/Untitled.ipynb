# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\harik\\Desktop\\Data-Sciences\\Notes\\Notes4\\04-CNNs'

# %%
url = "C:\\Users\\harik\\Desktop\\48775.jpg"

# %%
from PIL import Image
#Open image using Image module
im = Image.open(url)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1953x1093 at 0x268781C68B0>

# %%
im_gray = im.convert(mode="L")
im_array = np.asarray(im_gray)

# %%
plt.imshow(im_array, cmap = 'gray')

# %%
im_array.shape
# Out:
# (1093, 1953)

# %%
im.height, im.width
# Out:
# (1093, 1953)

# %%
1093/5
# Out:
# 218.6

# %%
x = 15
y = 15
w = 210
h = 210
cropped = im.crop((x,y,w,h))
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=195x195 at 0x26877FEEE20>

# %%
x = 225
y = 15
w = 205
h = 205
cropped = im.crop((x,y,x+w,y+h))
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=205x205 at 0x26877FEE3A0>

# %%
x = 15 + 8*(215)
y = 15 + 0*(215)
w = 180
h = 180
cropped = im.crop((x,y,x+w,y+h))
cropped.save('img\\9.png')

# %%
pwd
# Out:
# 'C:\\Users\\harik\\Desktop\\Data-Sciences\\Notes\\Notes4\\04-CNNs'

# %%
i = 0
k = 0
for m in range(5):
    for n in range(9):
        i+=1
        x = 15 + n*(215)
        y = 15 + m*(215)
        w = 180
        h = 180
        cropped = im.crop((x,y,x+w,y+h))
        j = i%10
        if j==9:
            k+=1
        cropped.save(f'img\\{j}_{k}.png')

# %%
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=180x180 at 0x268781E92B0>
