# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
def percent_missing(df):
    percent_nan = 100* df.isnull().sum() / len(df)
    percent_nan = percent_nan[percent_nan>0].sort_values()
    return percent_nan

# %%
missing = percent_missing(df)
plt.figure(figsize = (16,6))
sns.barplot(x = missing.index, y = missing)
plt.xticks(rotation = 90);

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df = df.drop([61,829])

# %%
missing = percent_missing(df)
plt.figure(figsize = (16,6))
sns.barplot(x = missing.index, y = missing)
plt.xticks(rotation = 90);

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 889, dtype: object

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005028 -0.035330  0.033681 -0.057686 -0.001657
# Survived       -0.005028  1.000000 -0.335549 -0.082446 -0.034040  0.083151
# Pclass         -0.035330 -0.335549  1.000000 -0.365902  0.081656  0.016824
# Age             0.033681 -0.082446 -0.365902  1.000000 -0.307351 -0.187896
# SibSp          -0.057686 -0.034040  0.081656 -0.307351  1.000000  0.414542
# Parch          -0.001657  0.083151  0.016824 -0.187896  0.414542  1.000000
# Fare            0.012703  0.255290 -0.548193  0.093143  0.160887  0.217532
#
#                  Fare
# PassengerId  0.012703
# Survived     0.255290
# Pclass      -0.548193
# Age          0.093143
# SibSp        0.160887
# Parch        0.217532
# Fare         1.000000

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# C23 C25 C27    4
# G6             4
# E101           3
# F2             3
#               ..
# A36            1
# E38            1
# D21            1
# C101           1
# E40            1
# Name: Cabin, Length: 146, dtype: int64

# %%
plt.figure(figsize = (16,6))
sns.scatterplot(data = df, x = 'Cabin', y= 'Survived')
plt.xticks(rotation = 90);

# %%
df[df['Cabin'] == 'B96 B98']
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 390          391         1       1                 Carter, Mr. William Ernest
# 435          436         1       1                  Carter, Miss. Lucile Polk
# 763          764         1       1  Carter, Mrs. William Ernest (Lucile Polk)
# 802          803         1       1        Carter, Master. William Thornton II
#
#         Sex   Age  SibSp  Parch  Ticket   Fare    Cabin Embarked
# 390    male  36.0      1      2  113760  120.0  B96 B98        S
# 435  female  14.0      1      2  113760  120.0  B96 B98        S
# 763  female  36.0      1      2  113760  120.0  B96 B98        S
# 802    male  11.0      1      2  113760  120.0  B96 B98        S

# %%
df[df['Cabin'] == 'G6']
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 205          206         0       3
# 251          252         0       3
# 394          395         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 205                         Strom, Miss. Telma Matilda  female   2.0      0
# 251         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
#
#      Parch   Ticket     Fare Cabin Embarked
# 10       1  PP 9549  16.7000    G6        S
# 205      1   347054  10.4625    G6        S
# 251      1   347054  10.4625    G6        S
# 394      2  PP 9549  16.7000    G6        S

# %%
df = df.drop('Cabin', axis = 1)

# %%
missing = percent_missing(df)
plt.figure(figsize = (16,6))
sns.barplot(x = missing.index, y = missing)
plt.xticks(rotation = 90);

# %%
sns.displot(data = df, x = 'Age', hue = 'Sex')

# %%
sns.scatterplot(data = df, x = 'Age', y = np.arange(len(df)), hue = 'Sex')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.iloc[15:20]
# Out:
#     PassengerId  Survived  Pclass  \
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch  Ticket    Fare Embarked
# 15      0  248706  16.000        S
# 16      1  382652  29.125        Q
# 17      0  244373  13.000        S
# 18      0  345763  18.000        S
# 19      0    2649   7.225        C

# %%
sns.pairplot(hue = 'Sex', data = df)

# %%
sns.kdeplot(data = df, x = 'Age', hue = 'Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   430.932692  0.740385  2.166667  27.745174  0.698718  0.653846
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.252124
# male    25.523893

# %%
plt.figure(figsize = (16,6))
sns.scatterplot(data = df, x = 'Age', y = 'Pclass', hue = 'Sex')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %%
df3 = df.groupby(['Pclass', 'Sex']).mean()

# %%
df4 = df[df['Age'].notnull()]

# %%
df4.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    bool
#  1   Survived     712 non-null    bool
#  2   Pclass       712 non-null    bool
#  3   Name         712 non-null    bool
#  4   Sex          712 non-null    bool
#  5   Age          712 non-null    bool
#  6   SibSp        712 non-null    bool
#  7   Parch        712 non-null    bool
#  8   Ticket       712 non-null    bool
#  9   Fare         712 non-null    bool
#  10  Embarked     712 non-null    bool
# dtypes: bool(11)
# memory usage: 13.2 KB

# %%
df3
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.717391  0.967391  34.240964  0.565217  0.467391
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.693750
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
df[(df['Pclass'] == 1) & (df['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# ...

# %%
df3.loc[(1,'male')]
# Out:
# PassengerId    455.729508
# Survived         0.368852
# Age             41.281386
# SibSp            0.311475
# Parch            0.278689
# Fare            67.226127
# Name: (1, male), dtype: float64

# %%
df3.loc[(1,'female')]['Age']
# Out:
# 34.24096385542169

# %%
classes = [1,2,3]
Sex = ['male', 'female']
for c in classes:
    for s in Sex:
        df_new = df[(df['Pclass'] == c) & (df['Sex'] == s)].fillna(df3.loc[(c,s)]['Age'])
        df4 = pd.concat([df4, df_new], axis = 0)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1601 entries, 0 to 888
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1601 non-null   int64
#  1   Survived     1601 non-null   int64
#  2   Pclass       1601 non-null   int64
#  3   Name         1601 non-null   object
#  4   Sex          1601 non-null   object
#  5   Age          1601 non-null   float64
#  6   SibSp        1601 non-null   int64
#  7   Parch        1601 non-null   int64
#  8   Ticket       1601 non-null   object
#  9   Fare         1601 non-null   float64
#  10  Embarked     1601 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 150.1+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df5 = df4.drop_duplicates()

# %%
final_df = df5.sort_index()

# %%
final_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                             Allen, Mr. William Henry    male  35.00      0
# ...

# %%
df['Age'].fillna()
# Out:
# 29.64209269662921

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 83.3+ KB

# %%
final_df.to_csv('final_titatic.csv', index = False)

# %%
data = pd.read_csv('final_titatic.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.5+ KB

# %%
df = pd.read_csv('titanic_nonull.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.5+ KB

# %%
df = df.drop('Name', axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    object
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Ticket       889 non-null    object
#  8   Fare         889 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.6+ KB

# %%
df['Fare'] = df['Fare'].apply(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    object
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Ticket       889 non-null    object
#  8   Fare         889 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.6+ KB

# %%
df.to_csv('titanic_final', index = False)
